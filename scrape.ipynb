# %%
import pandas as pd, requests, datetime as dt, re
from bs4 import BeautifulSoup
from selenium import webdriver
from time import sleep

# %%
url = 'https://truckersedge.dat.com'
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
element_list = driver.find_elements_by_tag_name('dat-search-result-row')

for item in element_list :
    driver.execute_script("arguments[0].scrollIntoView();", item)

# %%
driver = webdriver.Chrome(executable_path="./chromedriver/macos/chromedriver")

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')

# %%
now = datetime.datetime.now()

# %%
prev_length = 0

# %%
rows=[]

# %%
element_list = driver.find_elements_by_tag_name('dat-search-result-row')

for item in element_list :
    driver.execute_script("arguments[0].scrollIntoView();", item)

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
for tag in soup.find_all('dat-search-result-row'):
    for taga in tag.find_all('div', {'class':'ng-star-inserted'})[0:1]:
        age = taga.text
        length = len(age)
        if length < prev_length-1:
            break
        hr_min = re.split('\D+', age)
        hr = int(hr_min[-3] or 0)
        mi = int(hr_min[-2])
        posted = now - datetime.timedelta(hours=hr, minutes=mi)
        posted = posted.strftime('%H:%M')
    for taga in tag.find_all('a')[0:1]:
        miles = taga.text
    for taga in tag.find_all('span')[3:4]:
        date = taga.text
    for taga in tag.find_all('span')[4:5]:
        origin = taga.text
    for taga in tag.find_all('span')[13:14]:
        dest = taga.text
    for taga in tag.find_all('span')[25:26]:
        weight = taga.text
    for taga in tag.find_all('span')[28:29]:
        shipper = taga.text
        if shipper == '—':
            for taga in tag.find_all('span')[29:30]:
                shipper = taga.text
 
    if length < prev_length-1:
        break
    
#    print(num, age, hr, min, posted, miles, date, origin, dest, weight, shipper[:24])
#    num += 1
    
    row = {'posted': posted, 'miles': miles, 'origin': origin, 'dest': dest, 
            'weight': weight, 'shipper': shipper}
    rows.append(row)
    prev_length = length

# %%
len(rows)
# Out:
# 0

# %%
cols = ['posted', 'miles', 'origin', 'dest', 'weight', 'shipper', 'time']

# %%
df = pd.DataFrame(rows, columns=cols)

# %%
df.set_index('posted')
# Out:
#           miles             origin              dest  weight  \
# posted
# 11:14    1,406    City Of Indus,CA        Roanoke,TX  24,000
# 11:11    1,362        San Diego,CA         Dallas,TX  14,000
# 11:11    1,423    City Of Indus,CA         Dallas,TX  42,000
# 11:08    1,357            Vista,CA       Ft Worth,TX  25,000
# 11:06    1,423    City Of Indus,CA         Dallas,TX  41,800
# 11:04    1,423    City Of Indus,CA         Dallas,TX  43,900
# 11:04    1,462          Shafter,CA  Grand Prairie,TX  45,000
# 11:03    1,527         Eastvale,CA    Mt Pleasant,TX  42,000
# 10:53    1,527         Eastvale,CA    Mt Pleasant,TX  42,000
# 10:25    1,423    City Of Indus,CA         Dallas,TX  42,000
# 10:23    1,390   San Bernardino,CA         Dallas,TX  19,000
# 10:06    1,440      Los Angeles,CA         Dallas,TX  25,000
# 09:18    1,360        San Diego,CA     Lewisville,TX  25,000
# 06:05    1,433    Santa Fe Spgs,CA     Carrollton,TX  40,000
# ...

# %%
df1 = df1[df1['posted']<'13']

# %%
df0.shape
# Out:
# (15, 7)

# %%
match = ['miles', 'origin', 'dest', 'shipper']

# %%
df0[match].head()
# Out:
#      miles            origin         dest  \
# 0   1,406   City Of Indus,CA   Roanoke,TX
# 1   1,362       San Diego,CA    Dallas,TX
# 2   1,423   City Of Indus,CA    Dallas,TX
# 3   1,357           Vista,CA  Ft Worth,TX
# 4   1,423   City Of Indus,CA    Dallas,TX
#
#                                              shipper
# 0  Arnold Transportation Services Inc, Grand Prai...
# 1                    Tristar Transit Inc, Sylmar, CA
# 2                       R2 Logistics Inc, Dallas, TX
# 3               Landstar Ranger Inc, San Antonio, TX
# 4                       R2 Logistics Inc, Dallas, TX

# %%
df1 = pd.DataFrame(rows, columns=cols)
df1.set_index('posted')
# Out:
#           miles             origin              dest  weight  \
# posted
# 11:48    1,360        San Diego,CA     Lewisville,TX  25,000
# 11:48    1,362        San Diego,CA         Dallas,TX  14,000
# 11:41    1,423    City Of Indus,CA         Dallas,TX  41,800
# 11:35    1,406    City Of Indus,CA        Roanoke,TX  10,000
# 11:33    1,390   San Bernardino,CA         Dallas,TX  19,000
# 11:33    1,380        San Diego,CA          Allen,TX       —
# 11:31    1,423    City Of Indus,CA         Dallas,TX  42,000
# 11:09    1,462          Shafter,CA  Grand Prairie,TX  45,000
# 11:08    1,527         Eastvale,CA    Mt Pleasant,TX  42,000
# 10:58    1,527         Eastvale,CA    Mt Pleasant,TX  42,000
# 10:30    1,423    City Of Indus,CA         Dallas,TX  42,000
# 06:10    1,433    Santa Fe Spgs,CA     Carrollton,TX  40,000
# 05:02    1,360        San Diego,CA     Lewisville,TX  25,000
# 14:04    1,402      Pico Rivera,CA       Rockwall,TX   6,000
# ...

# %%
df2 = pd.DataFrame(rows, columns=cols)
df2.set_index('posted')
# Out:
#           miles             origin               dest  weight  \
# posted
# 14:00    1,438           Carson,CA          Irving,TX  30,000
# 13:59    1,420        Fullerton,CA  Farmers Branch,TX  12,000
# 13:58    1,452          Ontario,CA            Waco,TX  15,000
# 13:56    1,440      Los Angeles,CA          Dallas,TX  41,800
# 13:51    1,328        San Diego,CA        Ft Worth,TX  45,000
# 13:48    1,438           Carson,CA          Irving,TX  25,000
# 13:40    1,423    City Of Indus,CA          Dallas,TX  41,800
# 13:10    1,390   San Bernardino,CA          Dallas,TX  19,000
# 13:05    1,527         Eastvale,CA     Mt Pleasant,TX  42,000
# 12:31    1,360        San Diego,CA      Lewisville,TX  25,000
# 12:31    1,360        San Diego,CA      Lewisville,TX  25,000
#
#                                                shipper  time
# posted
# 14:00                   Landstar Ranger Inc, Tampa, FL   NaN
# 13:59   New Wave International Cargo Inc, Hodgkins, IL   NaN
# ...

# %%
df3 = pd.DataFrame(rows, columns=cols)
df3.set_index('posted')
# Out:
#                   miles             origin           dest  weight  \
# posted
# 14:33            1,359            Boron,CA      Dallas,TX  41,503
# 14:18            1,364        Mira Loma,CA    Ft Worth,TX  42,100
# 14:14            1,382    Moreno Valley,CA      Dallas,TX   9,672
# 14:14            1,382    Moreno Valley,CA      Dallas,TX  40,000
# 14:11            1,390   San Bernardino,CA      Dallas,TX  19,000
# 14:10            1,328        San Diego,CA    Ft Worth,TX  45,000
# 14:09            1,417        Fullerton,CA     Coppell,TX  40,000
# 14:05            1,423    City Of Indus,CA      Dallas,TX  41,800
# 14:01            1,359            Boron,CA      Dallas,TX  41,000
# 14:01            1,359            Boron,CA      Dallas,TX  41,000
# 14:01            1,438           Carson,CA      Irving,TX  30,000
# 14:01            1,438           Carson,CA      Irving,TX  30,000
# 13:57            1,440      Los Angeles,CA      Dallas,TX  41,800
# ...

# %%
df4 = pd.DataFrame(rows, columns=cols)
df4.set_index('posted')
# Out:
#                   miles             origin             dest  weight  \
# posted
# 15:00            1,382    Moreno Valley,CA        Dallas,TX   9,672
# 15:00            1,382    Moreno Valley,CA        Dallas,TX  40,000
# 14:49            1,402          Ontario,CA  Flower Mound,TX  45,000
# 14:46   \n\n\n\n 1,316           Vernon,CA        Humble,TX  40,000
# 14:42            1,390   San Bernardino,CA        Dallas,TX       —
# 14:36            1,501           Oxnard,CA        Dallas,TX  38,000
# 14:36            1,360        San Diego,CA    Lewisville,TX  25,000
# 14:18            1,364        Mira Loma,CA      Ft Worth,TX  42,100
# 14:11            1,390   San Bernardino,CA        Dallas,TX  19,000
# 14:10            1,328        San Diego,CA      Ft Worth,TX  45,000
# 14:04            1,423    City Of Indus,CA        Dallas,TX  41,800
# 14:01            1,359            Boron,CA        Dallas,TX  41,000
# 14:01            1,359            Boron,CA        Dallas,TX  41,000
# ...

# %%
df5 = pd.DataFrame(rows, columns=cols)
df5.set_index('posted')
# Out:
#                   miles             origin             dest  weight  \
# posted
# 15:31            1,359            Boron,CA        Dallas,TX  41,503
# 15:16            1,390   San Bernardino,CA        Dallas,TX  19,000
# 15:06            1,359            Boron,CA        Dallas,TX  41,000
# 15:06            1,359            Boron,CA        Dallas,TX  41,000
# 14:49            1,402          Ontario,CA  Flower Mound,TX  45,000
# 14:46   \n\n\n\n 1,316           Vernon,CA        Humble,TX  40,000
# 14:42            1,390   San Bernardino,CA        Dallas,TX       —
# 14:36            1,501           Oxnard,CA        Dallas,TX  38,000
# 14:36            1,360        San Diego,CA    Lewisville,TX  25,000
# 14:18            1,364        Mira Loma,CA      Ft Worth,TX  42,100
# 14:04            1,423    City Of Indus,CA        Dallas,TX  41,800
# 13:56            1,440      Los Angeles,CA        Dallas,TX  41,800
# 13:45            1,428       Buena Park,CA        Dallas,TX   9,200
# ...

# %%
df6 = pd.DataFrame(rows, columns=cols)
df6.set_index('posted')
# Out:
#                   miles             origin        dest  weight  \
# posted
# 16:00            1,382    Moreno Valley,CA   Dallas,TX   9,672
# 16:00            1,382    Moreno Valley,CA   Dallas,TX  40,000
# 16:00            1,407        Fullerton,CA  Roanoke,TX  20,112
# 15:51            1,390   San Bernardino,CA   Dallas,TX       —
# 15:51   \n\n\n\n 1,316           Vernon,CA   Humble,TX  40,000
# 15:41            1,501           Oxnard,CA   Dallas,TX  38,000
# 15:36            1,303         Beaumont,CA  Coppell,TX  28,000
# 15:36            1,303         Beaumont,CA  Coppell,TX  28,000
# 15:36            1,303         Beaumont,CA  Coppell,TX  28,575
# 15:36            1,303         Beaumont,CA  Coppell,TX  28,575
# 15:36            1,303         Beaumont,CA  Coppell,TX  28,575
# 15:35            1,538          Ventura,CA  Terrell,TX   7,100
# 15:35            1,538          Ventura,CA  Terrell,TX   7,100
# 15:30            1,359            Boron,CA   Dallas,TX  41,503
# ...

# %%
df61 = pd.DataFrame(rows, columns=cols)
df61.set_index('posted')
# Out:
#                   miles             origin             dest  weight  \
# posted
# 15:51            1,390   San Bernardino,CA        Dallas,TX       —
# 15:51   \n\n\n\n 1,316           Vernon,CA        Humble,TX  40,000
# 15:41            1,501           Oxnard,CA        Dallas,TX  38,000
# 15:36            1,303         Beaumont,CA       Coppell,TX  28,000
# 15:36            1,303         Beaumont,CA       Coppell,TX  28,000
# 15:36            1,303         Beaumont,CA       Coppell,TX  28,575
# 15:36            1,303         Beaumont,CA       Coppell,TX  28,575
# 15:36            1,303         Beaumont,CA       Coppell,TX  28,575
# 15:35            1,538          Ventura,CA       Terrell,TX   7,100
# 15:35            1,538          Ventura,CA       Terrell,TX   7,100
# 15:30            1,359            Boron,CA        Dallas,TX  41,503
# 15:16            1,390   San Bernardino,CA        Dallas,TX  19,000
# 15:06            1,359            Boron,CA        Dallas,TX  41,000
# ...

# %%
df7 = pd.DataFrame(rows, columns=cols)
df7.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 16:18    1,402          Ontario,CA  Flower Mound,TX  45,000
# 16:15    1,390   San Bernardino,CA        Dallas,TX  19,000
# 16:10    1,359            Boron,CA        Dallas,TX  41,000
# 16:10    1,359            Boron,CA        Dallas,TX  41,000
# 16:00    1,407        Fullerton,CA       Roanoke,TX  20,112
# 15:51    1,390   San Bernardino,CA        Dallas,TX       —
# 15:40    1,501           Oxnard,CA        Dallas,TX  38,000
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:35    1,538          Ventura,CA       Terrell,TX   7,100
# 15:34    1,538          Ventura,CA       Terrell,TX   7,100
# ...

# %%
df8 = pd.DataFrame(rows, columns=cols)
df8.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 16:57    1,402          Ontario,CA  Flower Mound,TX  45,000
# 16:48    1,501           Oxnard,CA        Dallas,TX  38,000
# 16:47    1,423    City Of Indus,CA        Dallas,TX  26,000
# 16:43    1,360        San Diego,CA    Lewisville,TX  25,000
# 16:18    1,390   San Bernardino,CA        Dallas,TX  19,000
# 16:13    1,359            Boron,CA        Dallas,TX  41,000
# 16:13    1,359            Boron,CA        Dallas,TX  41,000
# 16:02    1,407        Fullerton,CA       Roanoke,TX  20,112
# 15:54    1,390   San Bernardino,CA        Dallas,TX       —
# 15:38    1,303         Beaumont,CA       Coppell,TX  28,000
# 15:38    1,303         Beaumont,CA       Coppell,TX  28,000
# 15:38    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:38    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:38    1,303         Beaumont,CA       Coppell,TX  28,575
# ...

# %%
df9 = pd.DataFrame(rows, columns=cols)
df9.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 17:24    1,423    City Of Indus,CA        Dallas,TX  26,000
# 17:20    1,390   San Bernardino,CA        Dallas,TX  19,000
# 17:10    1,359            Boron,CA        Dallas,TX  41,000
# 17:10    1,359            Boron,CA        Dallas,TX  41,000
# 17:01    1,390   San Bernardino,CA        Dallas,TX       —
# 16:55    1,402          Ontario,CA  Flower Mound,TX  45,000
# 16:45    1,501           Oxnard,CA        Dallas,TX  38,000
# 16:40    1,360        San Diego,CA    Lewisville,TX  25,000
# 15:59    1,407        Fullerton,CA       Roanoke,TX  20,112
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 15:35    1,303         Beaumont,CA       Coppell,TX  28,575
# ...

# %%
df10 = pd.DataFrame(rows, columns=cols)
df10.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 18:00    1,407        Fullerton,CA       Roanoke,TX  20,112
# 17:59    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 17:59    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 17:51    1,423    City Of Indus,CA        Dallas,TX  26,000
# 17:50    1,501           Oxnard,CA        Dallas,TX  38,000
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:35    1,359            Boron,CA        Dallas,TX  41,503
# 17:20    1,390   San Bernardino,CA        Dallas,TX  19,000
# 17:10    1,359            Boron,CA        Dallas,TX  41,000
# 17:10    1,359            Boron,CA        Dallas,TX  41,000
# ...

# %%
# Out:
#           miles             origin             dest  weight  \
# posted
# 18:26    1,390   San Bernardino,CA        Dallas,TX  19,000
# 18:16    1,359            Boron,CA        Dallas,TX  41,000
# 18:16    1,359            Boron,CA        Dallas,TX  41,000
# 18:12    1,390   San Bernardino,CA        Dallas,TX       —
# 18:01    1,407        Fullerton,CA       Roanoke,TX  20,112
# 18:00    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 18:00    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 17:51    1,501           Oxnard,CA        Dallas,TX  38,000
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:36    1,359            Boron,CA        Dallas,TX  41,503
# ...

# %%
df12 = pd.DataFrame(rows, columns=cols)
df12.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 18:51    1,501           Oxnard,CA        Dallas,TX  38,000
# 18:40    1,360        San Diego,CA    Lewisville,TX  25,000
# 18:26    1,390   San Bernardino,CA        Dallas,TX  19,000
# 18:15    1,359            Boron,CA        Dallas,TX  41,000
# 18:15    1,359            Boron,CA        Dallas,TX  41,000
# 18:11    1,390   San Bernardino,CA        Dallas,TX       —
# 18:00    1,407        Fullerton,CA       Roanoke,TX  20,112
# 18:00    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 18:00    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:35    1,303         Beaumont,CA       Coppell,TX  28,575
# ...

# %%
df13 = pd.DataFrame(rows, columns=cols)
df13.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 19:21    1,390   San Bernardino,CA        Dallas,TX       —
# 19:21    1,359            Boron,CA        Dallas,TX  41,000
# 19:21    1,359            Boron,CA        Dallas,TX  41,000
# 18:51    1,501           Oxnard,CA        Dallas,TX  38,000
# 18:41    1,360        San Diego,CA    Lewisville,TX  25,000
# 18:26    1,390   San Bernardino,CA        Dallas,TX  19,000
# 18:01    1,407        Fullerton,CA       Roanoke,TX  20,112
# 18:00    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 18:00    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,000
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,575
# 17:36    1,303         Beaumont,CA       Coppell,TX  28,575
# ...

# %%
df14 = pd.DataFrame(rows, columns=cols)
df14.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 20:05    1,407        Fullerton,CA       Roanoke,TX  20,112
# 20:00    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 20:00    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 19:55    1,501           Oxnard,CA        Dallas,TX  38,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,359            Boron,CA        Dallas,TX  41,503
# 19:30    1,390   San Bernardino,CA        Dallas,TX  19,000
# 19:21    1,390   San Bernardino,CA        Dallas,TX       —
# 19:20    1,359            Boron,CA        Dallas,TX  41,000
# 19:20    1,359            Boron,CA        Dallas,TX  41,000
# ...

# %%
df15 = pd.DataFrame(rows, columns=cols)
df15.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 20:35    1,390   San Bernardino,CA        Dallas,TX  19,000
# 20:25    1,359            Boron,CA        Dallas,TX  41,000
# 20:25    1,359            Boron,CA        Dallas,TX  41,000
# 20:05    1,407        Fullerton,CA       Roanoke,TX  20,112
# 20:00    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 20:00    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 19:55    1,501           Oxnard,CA        Dallas,TX  38,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,359            Boron,CA        Dallas,TX  41,503
# 19:21    1,390   San Bernardino,CA        Dallas,TX       —
# ...

# %%
df15 = pd.DataFrame(rows, columns=cols)
df15.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 21:01    1,501           Oxnard,CA        Dallas,TX  38,000
# 20:46    1,360        San Diego,CA    Lewisville,TX  25,000
# 20:42    1,390   San Bernardino,CA        Dallas,TX       —
# 20:36    1,390   San Bernardino,CA        Dallas,TX  19,000
# 20:26    1,359            Boron,CA        Dallas,TX  41,000
# 20:26    1,359            Boron,CA        Dallas,TX  41,000
# 20:06    1,407        Fullerton,CA       Roanoke,TX  20,112
# 20:01    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 20:01    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 19:41    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:41    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:41    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:41    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:41    1,303         Beaumont,CA       Coppell,TX  28,575
# ...

# %%
df16 = pd.DataFrame(rows, columns=cols)
df16.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 21:30    1,359            Boron,CA        Dallas,TX  41,000
# 21:30    1,359            Boron,CA        Dallas,TX  41,000
# 21:00    1,501           Oxnard,CA        Dallas,TX  38,000
# 20:45    1,360        San Diego,CA    Lewisville,TX  25,000
# 20:41    1,390   San Bernardino,CA        Dallas,TX       —
# 20:35    1,390   San Bernardino,CA        Dallas,TX  19,000
# 20:05    1,407        Fullerton,CA       Roanoke,TX  20,112
# 20:00    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 20:00    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,000
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# 19:40    1,303         Beaumont,CA       Coppell,TX  28,575
# ...

# %%
df17 = pd.DataFrame(rows, columns=cols)
df17.set_index('posted')
# Out:
#           miles             origin             dest  weight  \
# posted
# 22:01    1,501           Oxnard,CA        Dallas,TX  38,000
# 22:01    1,382    Moreno Valley,CA        Dallas,TX  40,000
# 22:01    1,382    Moreno Valley,CA        Dallas,TX   9,672
# 21:52    1,390   San Bernardino,CA        Dallas,TX       —
# 21:41    1,390   San Bernardino,CA        Dallas,TX  19,000
# 21:41    1,303         Beaumont,CA       Coppell,TX  28,000
# 21:41    1,303         Beaumont,CA       Coppell,TX  28,000
# 21:41    1,303         Beaumont,CA       Coppell,TX  28,575
# 21:41    1,303         Beaumont,CA       Coppell,TX  28,575
# 21:41    1,303         Beaumont,CA       Coppell,TX  28,575
# 21:41    1,359            Boron,CA        Dallas,TX  41,503
# 21:31    1,359            Boron,CA        Dallas,TX  41,000
# 21:31    1,359            Boron,CA        Dallas,TX  41,000
# 20:46    1,360        San Diego,CA    Lewisville,TX  25,000
# ...

# %%
driver.find_element_by_id('search-new').click()
driver.find_element_by_id('searchform-search').click()

# %%
len(rows)
# Out:
# 0

# %%
df.to_csv('df.csv')
df61.to_csv('df61.csv')
df17.to_csv('df17.csv')

# %%
df10.to_csv('df10.csv')
df12.to_csv('df12.csv')
df13.to_csv('df13.csv')
df14.to_csv('df14.csv')
df15.to_csv('df15.csv')
df16.to_csv('df16.csv')
